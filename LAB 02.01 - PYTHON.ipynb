# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/20201.ai4eng/master/init.py
import init; init.init(force_download=False); init.get_weblink()
# Out:
# enabling encryption...
# encryption enabled
# replicating local resources
# endpoint https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
from local.lib.rlxmoocapi import submit, session
student = session.Session(init.endpoint).login( course_id=init.course_id, 
                                                session_id="UDEA", 
                                                lab_id="L02.01" )
init.get_weblink()
# Out:
# username: davida.torres@udea.edu.co
# password: ··········
# endpoint https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
import numpy as np

# %% [markdown]
# # Task 1: Palindrome
#
# Determine whether an integer number $n$ is a palindrome, this is, if it is the same number when read left to right and when read right to left. Return `True` if so, otherwise return `False`.
#
# **Execution example**
#
# ```python
# >>> palindromo(n=3456543)
# True
#
# >>> palindromo(n=543)
# False
# ```
#
# **hint**: transform it into string, reverse it and check equality
#
# **challenge**: use one single line of code

# %%
def palindromo(n): 
    return str(n) == str(n)[::-1]

# %% [markdown]
# check your code manually

# %%
print (palindromo(12321))
print (palindromo(12322))
# Out:
# True
# False

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_01");
# Out:
#                 <b>task_01 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                 <p/><pre>----- grader message -------</pre>testing with 100 random calls<br/><b>correct</b><pre>----------------------------</pre>
#                 <p/><p/>
#                 <div style="font-size:10px"><b>SUBMISSION CODE</b> zFLTn0iGgQPi5OQnWcX/3PGhEcBTWMLB7hlJDEixdMCzKMdwVsbRS1W+73V7RygOYlerq+d6SAbueDw2mff2Nl0x5QWHXZXcPorioSGQKLa0loFdWtqmyroDQWgNtSytYvjg9WrjCyQnmp8y2UOrPA==</div>

# %% [markdown]
# # Task 2: Money Change
#
# En este ejercicio, su programa recibirá un monto entre 1 y 99 centavos de Dolar, Escriba un metodo que retorne en una lista, cuantas monedas son necesarias para devolverle a alguien dicho valor, si únicamente se cuenta con monedas de 1, 10 y 25 centavos. La lista debe entregarse de la siguiente manera:
#
# In this task your function will receive an amount between 1 and 99 cents and will have to return a list with three numbers [$n_1$, $n_{10}$, $n_{25}$], specifying how many coins of 1, 10 and 25 cents are required to obtain the given amonut. We only have coints of 1, 10 and 25 cents. There are no other kinds of coins.
#
# If the amount given is less than 1 or more than 99 you must return `None`.
#
# **Execution example**
#
# ```python
# >>> cambio(n=55)
# [5,0,2]
#
# >>> cambio(n=200)
# None
#
# >>> cambio(n=47)
# [2,2,1]
# ```

# %%
def change_money(n):
    if n >=1 and n<=99:
      r = [0,0,0]
      if n>=25:
          r[2]=n//25
          n=n%25
      if n>=10:
          r[1]=n//10
          n=n%10
      r[0]=n
      return r
    return None
# Out:
# '\ndef change_money(n):\n    if n >=1 and n<=99:\n      r = [0,0,0]\n      if n>=25:\n          r[2]=n//25\n          n=n%25\n      if n>=10:\n          r[1]=n//10\n          n=n%10\n      r[0]=n\n      return r\n    return None\n  \n'

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_02");
# Out:
#                 <b>task_02 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                 <p/><pre>----- grader message -------</pre>testing with 100 random calls<br/><b>correct</b><pre>----------------------------</pre>
#                 <p/><p/>
#                 <div style="font-size:10px"><b>SUBMISSION CODE</b> U0LZZ8NUUee6/5dBBX0lbJHlGmgn0UqUfSNolYBHb6aa2dmc34mzi9rSYACZvkqXUVxAcI+NcdVXPeE5LBfOdC0ca8viQOAIZmyXhw22gM8fiUnT4RNl/C/EEeUwMpP8TmK3LMnZABiAq60PUZUIVg==</div>

# %% [markdown]
# # Task 3: Fibonacci
#
# Complete the function below so that given an integer $n$ it computes the $n^{th}$ term of the Fibonacci series:
#
# $$ f_n = f_{n-1}+f_{n-2}$$
#
# Where $$f_0=0 \:\:\text{ y }\:\:f_1=1 $$ so that: $$f_2=1+0=1$$ $$f_3=1+1=2$$ $$f_4=2+1=3$$ and so on
#
# ### Execution example
# ```python
#
# >>> fibonacci(50)
# 12586269025
#
# >>> fibonacci(63)
# 6557470319842
# ```

# %%
def fibonacci(n):
   counter = 0

   first = 0
   second = 1
   temp = 0
   r=0
   while counter <= n:
      r=first
      temp = first + second
      first = second
      second = temp
      counter = counter + 1
   return r

# %% [markdown]
# **check manually your code**

# %%
fibonacci(17)
# Out:
# 1597

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_03");
# Out:
#                 <b>task_03 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                 <p/><pre>----- grader message -------</pre>testing with 100 random calls<br/><b>correct</b><pre>----------------------------</pre>
#                 <p/><p/>
#                 <div style="font-size:10px"><b>SUBMISSION CODE</b> 7bUUAiJaSFPnIqchfMzRlOtliuFOzjVKkfFZN0IjB26HTTdkJAYAXh3iklMRZQHVOXDQBEUAjvntDsUMblNE2dBbrKC54hOO8wUaOpD+rNJbalndZ2+jvbXtw0GpAm9rzihXoCl14rjyFMJxXsydcQ==</div>

# %% [markdown]
# # Task 4: Perfect number
#
# complete the following function so that it accepts an integer $n$ and returns `True` if $n$ is a perfect number and `False` otherwise.
#
# A perfect number is a positive integer that is equal to the sum of its positive divisors, excluding the number itself. For instance $6=3+2+1$
#
# See https://en.wikipedia.org/wiki/Perfect_number
#
# **Execution example**
# ```python
# >>> perfecto(6)
# True
#
# >>> perfecto(51)
# False
#
# >>> perfecto(496)
# True

# %%
def perfecto(n):
    sum=0
    for x in range(1,n):
      if n%x==0:
        sum+=x
    if sum==n :
      return True
    return False

# %% [markdown]
# **check your answer**

# %%
perfecto(6), perfecto(51), perfecto(496)
# Out:
# (True, False, True)

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_04");
# Out:
#                 <b>task_04 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                 <p/><pre>----- grader message -------</pre>testing with 100 random calls<br/><b>correct</b><pre>----------------------------</pre>
#                 <p/><p/>
#                 <div style="font-size:10px"><b>SUBMISSION CODE</b> juARUUApNHt/58rCTC1pcb8BDBeBUUrwxjjGNHZXrfXT/t6tshTgsdwmuIYeUc/cs38djq+h3JBuuGqpcPUu4qlhfUyvA2fcSb6fubUtKE/Gv4Rca3l8ux8WI7yZB67TbnyTy1wtSEajvDnqikjkCg==</div>
